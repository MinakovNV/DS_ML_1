# %% [markdown]
# # Lab 11/ Spotify data set 🤢🤢🤢
#
# Minakov Nikita, csse 1707DA
#
# @minakov.nv

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import pandas as pd
import nsfg
import first
import thinkstats2
import thinkplot

import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

from scipy import stats
import statistics 
import brfss
import random

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import statsmodels.formula.api as smf

# %% [markdown]
# ## Multiple regression

# %%
db_read = pd.read_csv('SpotifyFeatures.csv', delimiter = ',')
db_read
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
db_read.corr
# Out:
# <bound method DataFrame.corr of         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# ...

# %% [markdown]
# Here's popularity as a function of tempo

# %%
formula = 'popularity ~ tempo'
model = smf.ols(formula, data=db_read)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1538.
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:39:03   Log-Likelihood:            -1.0046e+06
# No. Observations:              232725   AIC:                         2.009e+06
# Df Residuals:                  232723   BIC:                         2.009e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     35.5140      0.148    240.009      0.000      35.224      35.804
# ...

# %% [markdown]
# We can extract the parameters.

# %%
inter = results.params['Intercept']
slope = results.params['tempo']
inter, slope
# Out:
# (35.51398509741364, 0.047706979213790385)

# %% [markdown]
# And the p-value of the slope estimate.

# %%
slope_pvalue = results.pvalues['tempo']
print(slope_pvalue)
# Out:
# 0.0

# %% [markdown]
# And the coefficient of determination.

# %%
results.rsquared
# Out:
# 0.00656730466239841

# %%
popM = db_read[db_read['genre'] == 'Pop']
movieM = db_read[db_read['genre'] == 'Movie']

# %% [markdown]
# The difference in popularity between Pop and movie songs.

# %%
diff_weight = popM.popularity.mean() - movieM.popularity.mean()
diff_weight
# Out:
# 54.41657010219974

# %% [markdown]
# The difference in tempo between Pop and Movie songs.

# %%
diff_age = popM.tempo.mean() - movieM.tempo.mean()
diff_age
# Out:
# 7.229074315522226

# %% [markdown]
# The age difference plausibly explains about half of the difference in popularity.

# %%
slope * diff_age
# Out:
# 0.3448772981055648

# %% [markdown]
# Running a single regression with a categorical variable, `isGkey`:

# %%
db_read['isGkey'] = db_read.key == 'G#'
formula = 'popularity ~ isGkey'
results = smf.ols(formula, data=db_read).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     152.5
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):           5.05e-35
# Time:                        10:44:28   Log-Likelihood:            -1.0053e+06
# No. Observations:              232725   AIC:                         2.011e+06
# Df Residuals:                  232723   BIC:                         2.011e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# Now finally running a multiple regression:

# %%
formula = 'popularity ~ isGkey + tempo'
results = smf.ols(formula, data=db_read).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     845.5
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:44:48   Log-Likelihood:            -1.0045e+06
# No. Observations:              232725   AIC:                         2.009e+06
# Df Residuals:                  232722   BIC:                         2.009e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# As expected, when we control for popularity, the apparent difference due to `isGkey` is cut in half.
#
# If we add age squared, we can control for a quadratic relationship between popularity and tempo.

# %%
db_read['isGkey'] = db_read.energy**2
formula = 'popularity ~ isGkey + tempo + tempo'
results = smf.ols(formula, data=db_read).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     4363.
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:45:55   Log-Likelihood:            -1.0010e+06
# No. Observations:              232725   AIC:                         2.002e+06
# Df Residuals:                  232722   BIC:                         2.002e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     33.6708      0.147    228.473      0.000      33.382      33.960
# ...

# %% [markdown]
# ## Data Mining

# %% [markdown]
# And we can search for variables with explanatory power.
#
# Because we don't clean most of the variables, we are probably missing some good ones.

# %%
import patsy

def GoMining(df):
    """Searches for variables that predict birth weight.

    df: DataFrame of pregnancy records

    returns: list of (rsquared, variable name) pairs
    """
    variables = []
    for name in df.columns:
        try:
            if df[name].var() < 1e-7:
                continue

            formula = 'totalwgt_lb ~ agepreg + ' + name
            formula = formula.encode('ascii')

            model = smf.ols(formula, data=df)
            if model.nobs < len(df)/2:
                continue

            results = model.fit()
        except (ValueError, TypeError, patsy.PatsyError):
            continue
        
        variables.append((results.rsquared, name))

    return variables

# %%
variables = GoMining(db_read)

# %% [markdown]
# The following functions report the variables with the highest values of $R^2$.

# %%
import re

def ReadVariables():
    """Reads Stata dictionary files for NSFG data.

    returns: DataFrame that maps variables names to descriptions
    """
    vars1 = thinkstats2.ReadStataDct('2002FemPreg.dct').variables
    vars2 = thinkstats2.ReadStataDct('2002FemResp.dct').variables

    all_vars = vars1.append(vars2)
    all_vars.index = all_vars.name
    return all_vars

def MiningReport(variables, n=30):
    """Prints variables with the highest R^2.

    t: list of (R^2, variable name) pairs
    n: number of pairs to print
    """
    all_vars = ReadVariables()

    variables.sort(reverse=True)
    for r2, name in variables[:n]:
        key = re.sub('_r$', '', name)
        try:
            desc = all_vars.loc[key].desc
            if isinstance(desc, pd.Series):
                desc = desc[0]
            print(name, r2, desc)
        except (KeyError, IndexError):
            print(name, r2)

# %% [markdown]
# Some of the variables that do well are not useful for prediction because they are not known ahead of time.

# %%
MiningReport(variables)

# %% [markdown]
# Combining the variables that seem to have the most explanatory power.

# %%
formula = ('popularity ~ tempo  + key=="G"')
results = smf.ols(formula, data=db_read).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     836.0
# Date:                Thu, 14 Nov 2019   Prob (F-statistic):               0.00
# Time:                        10:50:04   Log-Likelihood:            -1.0045e+06
# No. Observations:              232725   AIC:                         2.009e+06
# Df Residuals:                  232722   BIC:                         2.009e+06
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Logistic regression

# %%
#import first
#live, firsts, others = first.MakeFrames()
#live = live[live.prglngth>30]
#live['boy'] = (live.babysex==1).astype(int)

db_read['pop50'] = (db_read.popularity == 50).astype(int)

# %%
model = smf.logit('pop50 ~ tempo', data=db_read)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.110459
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                  pop50   No. Observations:               232725
# Model:                          Logit   Df Residuals:                   232723
# Method:                           MLE   Df Model:                            1
# Date:                Thu, 14 Nov 2019   Pseudo R-squ.:               0.0003538
# Time:                        11:41:16   Log-Likelihood:                -25707.
# converged:                       True   LL-Null:                       -25716.
# Covariance Type:            nonrobust   LLR p-value:                 1.992e-05
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Here are the variables that seemed most promising.

# %%
formula = 'pop50 ~ tempo + valence'
model = smf.logit(formula, data=db_read)
results = model.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.110451
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                  pop50   No. Observations:               232725
# Model:                          Logit   Df Residuals:                   232722
# Method:                           MLE   Df Model:                            2
# Date:                Thu, 14 Nov 2019   Pseudo R-squ.:               0.0004271
# Time:                        11:43:27   Log-Likelihood:                -25705.
# converged:                       True   LL-Null:                       -25716.
# Covariance Type:            nonrobust   LLR p-value:                 1.697e-05
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
endog = pd.DataFrame(model.endog, columns=[model.endog_names])
exog = pd.DataFrame(model.exog, columns=model.exog_names)

# %% [markdown]
# The baseline prediction strategy is to guess "pop50".

# %%
actual = endog['pop50']
baseline = actual.mean()
baseline
# Out:
# 0.023267805349661618

# %% [markdown]
# If we use the previous model, we can compute the number of predictions we get right.

# %%
predict = (results.predict() >= 0.5)
true_pos = predict * actual
true_neg = (1 - predict) * (1 - actual)
sum(true_pos), sum(true_neg)
# Out:
# (0.0, 227310.0)

# %% [markdown]
# Accuracy:

# %%
acc = (sum(true_pos) + sum(true_neg)) / len(actual)
acc
# Out:
# 0.9767321946503383

# %% [markdown]
# To make a prediction for an individual, we have to get their information into a `DataFrame`.

# %%
columns = ['popularity', 'valence', 'tempo', 'liveness']
new = pd.DataFrame([[35, 39, 3, 10]], columns=columns)
y = results.predict(new)
y
# Out:
# 0    0.512404
# dtype: float64

# %% [markdown]
# This person has a 51% chance of having a popularity 50 (according to the model).
