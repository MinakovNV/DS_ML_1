# %% [markdown]
# # Lab 8/ Spotify data set 🤢🤢🤢
#
# Minakov Nikita, csse 1707DA
#
# @minakov.nv

# %%
from __future__ import print_function, division

# %matplotlib inline

import numpy as np

import pandas as pd
import nsfg
import first
import thinkstats2
import thinkplot

import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns
from scipy import stats

import brfss

# %%
db_read = pd.read_csv('SpotifyFeatures.csv', delimiter = ',')

# %%
db_read
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %% [markdown]
# ## The sampling distribution
#
# The following function simulates experiments where we estimate the mean of a population using $\bar{x}$, and returns a list of estimates, one from each experiment.

# %%
popul = db_read.popularity
popul_sample = db_read.popularity.sample(100)

# %% [markdown]
# Here's the "distribution of the mean" which shows how much we should expect $\bar{x}$ to vary from one experiment to the next.

# %%
cdf = thinkstats2.Cdf(popul)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='mean',
                 ylabel='CDF')

# %% [markdown]
# Here's the "sampling distribution of the mean" which shows how much we should expect $\bar{x}$ to vary from one experiment to the next.

# %%
cdf = thinkstats2.Cdf(popul_sample)
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='Sample mean',
                 ylabel='CDF')

# %% [markdown]
# Mean of all data in Set

# %%
np.mean(popul)
# Out:
# 41.12750241701579

# %% [markdown]
# The mean of the sample means is close to the actual value of $\mu$.

# %%
np.mean(popul_sample)
# Out:
# 43.43

# %% [markdown]
# Both means are preaty close but have little bias.

# %% [markdown]
# An interval that contains 90% of the values in the sampling disrtribution is called a 90% confidence interval.

# %%
ci = cdf.Percentile(5), cdf.Percentile(95)
ci
# Out:
# (12, 65)

# %% [markdown]
# And the RMSE of the sample means is called the standard error.

# %%
stderr = RMSE(popul, 90)
stderr
# Out:
# 52.14780715384867

# %%
stderr = RMSE(popul_sample, 90)
stderr
# Out:
# 49.182618881064066

# %% [markdown]
# Confidence intervals and standard errors quantify the variability in the estimate due to random sampling.

# %% [markdown]
# ## Exercises

# %% [markdown]
# **Exercise:**  In this chapter we used $\bar{x}$ and median to estimate µ, and found that $\bar{x}$ yields lower MSE. Also, we used $S^2$ and $S_{n-1}^2$ to estimate σ, and found that $S^2$ is biased and $S_{n-1}^2$ unbiased.
# Run similar experiments to see if $\bar{x}$ and median are biased estimates of µ. Also check whether $S^2$ or $S_{n-1}^2$ yields a lower MSE.

# %%
def Estimate4(n=7, iters=100000):

    mu = 0
    sigma = 1

    means = []
    medians = []
    for _ in range(iters):
        xs = [random.gauss(mu, sigma) for i in range(n)]
        xbar = np.mean(xs)
        median = np.median(xs)
        means.append(xbar)
        medians.append(median)

    print('xbar', MeanError(means, mu))
    print('median', MeanError(medians, mu))
    
Estimate4()
# Out:
# xbar -0.0007902046076197237
# median 0.0003098119649461412

# %%
def Estimate5(n=7, iters=100000):

    mu = 0
    sigma = 1

    estimates1 = []
    estimates2 = []
    for _ in range(iters):
        xs = [random.gauss(mu, sigma) for i in range(n)]
        biased = np.var(xs)
        unbiased = np.var(xs, ddof=1)
        estimates1.append(biased)
        estimates2.append(unbiased)

    print('RMSE biased', RMSE(estimates1, sigma**2))
    print('RMSE unbiased', RMSE(estimates2, sigma**2))

Estimate5()
# Out:
# RMSE biased 0.5140185943438927
# RMSE unbiased 0.5758682096172361

# %% [markdown]
# **Exercise:** Suppose you draw a sample with size n=10 from an exponential distribution with λ=2. Simulate this experiment 1000 times and plot the sampling distribution of the estimate L. Compute the standard error of the estimate and the 90% confidence interval.
#
# Repeat the experiment with a few different values of `n` and make a plot of standard error versus `n`.

# %%
def SimulateSample(lam=2, n=10, iters=1000):

    def VertLine(x, y=1):
        thinkplot.Plot([x, x], [0, y], color='0.8', linewidth=3)

    estimates = []
    for _ in range(iters):
        xs = np.random.exponential(1.0/lam, n)
        lamhat = 1.0 / np.mean(xs)
        estimates.append(lamhat)

    stderr = RMSE(estimates, lam)
    print('standard error', stderr)

    cdf = thinkstats2.Cdf(estimates)
    ci = cdf.Percentile(5), cdf.Percentile(95)
    print('confidence interval', ci)
    VertLine(ci[0])
    VertLine(ci[1])

    thinkplot.Cdf(cdf)
    thinkplot.Config(xlabel='estimate',
                     ylabel='CDF',
                     title='Sampling distribution')

    return stderr

SimulateSample()
# Out:
# standard error 0.778677707728786
# confidence interval (1.2697412218109843, 3.672632974559394)
# 0.778677707728786

# %% [markdown]
# **Exercise:** In games like hockey and soccer, the time between goals is roughly exponential. So you could estimate a team’s goal-scoring rate by observing the number of goals they score in a game. This estimation process is a little different from sampling the time between goals, so let’s see how it works.
#
# Write a function that takes a goal-scoring rate, `lam`, in goals per game, and simulates a game by generating the time between goals until the total time exceeds 1 game, then returns the number of goals scored.
#
# Write another function that simulates many games, stores the estimates of `lam`, then computes their mean error and RMSE.
#
# Is this way of making an estimate biased?

# %%
def SimulateGame(lam):

    goals = 0
    t = 0
    while True:
        time_between_goals = random.expovariate(lam)
        t += time_between_goals
        if t > 1:
            break
        goals += 1

    L = goals
    return L

# %%
def Estimate6(lam=2, m=1000000):

    estimates = []
    for i in range(m):
        L = SimulateGame(lam)
        estimates.append(L)

    print('rmse L', RMSE(estimates, lam))
    print('mean error L', MeanError(estimates, lam))
    
    pmf = thinkstats2.Pmf(estimates)
    thinkplot.Hist(pmf)
    thinkplot.Config(xlabel='Goals scored', ylabel='PMF')
    
Estimate6()
# Out:
# rmse L 1.4154165464625599
# mean error L 0.000132
